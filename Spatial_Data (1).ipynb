# %%
import folium

# %%
# define the world map
world_map = folium.Map()

# display world map
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_00ab1dfd26bbacdf79bb6a3b42b34a15 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_00ab1dfd26bbacdf79bb6a3b42b34a15&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_00ab1dfd26bbacdf79bb6a3b42b34a15 = L.map(
#                 &quot;map_00ab1dfd26bbacdf79bb6a3b42b34a15&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dc31f60a7ad767cf62acc86df0b11a3f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_00ab1dfd26bbacdf79bb6a3b42b34a15);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def folium_deepnote_show(m):
    data = m.get_root().render()
    data_fixed_height = data.replace('width: 100%;height: 100%', 'width: 100%').replace('height: 100.0%;', 'height: 609px;', 1)
    display(HTML(data_fixed_height))

import folium
from folium.plugins import MarkerCluster
from IPython.display import display, Image


world_map = folium.Map(location=[0, 0], zoom_start=2)


places = [
    {"name": "New York City", "coords": [40.7128, -74.0060], "image_url": "https://source.unsplash.com/400x300/?newyork"},
    {"name": "London", "coords": [51.5074, -0.1278], "image_url": "https://source.unsplash.com/400x300/?london"},
    {"name": "Tokyo", "coords": [35.6895, 139.6917], "image_url": "https://source.unsplash.com/400x300/?tokyo"},
    {"name": "Sydney", "coords": [-33.85903383272798, 151.20364678216654], "image_url": "https://source.unsplash.com/400x300/?sydney"},
    {"name": "Taj Mahal", "coords": [27.17540725072536, 78.04222802682138], "image_url": "https://source.unsplash.com/400x300/?tajmahal"},
    {"name": "Sheikh Zayed Grand Mosque", "coords": [24.412999412921067, 54.47505047393601], "image_url": "https://source.unsplash.com/400x300/?Sheikh Zayed Grand Mosque"},

]


for place in places:
    popup_content = f"<b>{place['name']}</b><br><img src='{place['image_url']}' width='200px'>"
    folium.Marker(location=place["coords"], popup=folium.Popup(html=popup_content, max_width='auto')).add_to(world_map)

display(world_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d8ab33a78be96bc6fed0566df933291d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d8ab33a78be96bc6fed0566df933291d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d8ab33a78be96bc6fed0566df933291d = L.map(
#                 &quot;map_d8ab33a78be96bc6fed0566df933291d&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e0983c3136ab4796b264af23684dbb1c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d8ab33a78be96bc6fed0566df933291d);
#
#
#             var marker_48729705e92a9914810ee041b413791f = L.marker(
#                 [40.7128, -74.006],
#                 {}
#             ).addTo(map_d8ab33a78be96bc6fed0566df933291d);
#
#
#         var popup_a514053a48ddfc3fa2144b8933e8f9b6 = L.popup({&quot;maxWidth&quot;: &quot;auto&quot;});
#
#
#
#                 var html_550a49ceda907c94369096dc33f4dbbb = $(`&lt;div id=&quot;html_550a49ceda907c94369096dc33f4dbbb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;New York City&lt;/b&gt;&lt;br&gt;&lt;img src=&#x27;https://source.unsplash.com/400x300/?newyork&#x27; width=&#x27;200px&#x27;&gt;&lt;/div&gt;`)[0];
#                 popup_a514053a48ddfc3fa2144b8933e8f9b6.setContent(html_550a49ceda907c94369096dc33f4dbbb);
#
#
#
#         marker_48729705e92a9914810ee041b413791f.bindPopup(popup_a514053a48ddfc3fa2144b8933e8f9b6)
#         ;
#
#
#
#
#             var marker_bb0123a315e4ad4fcbf6bf5a716a15de = L.marker(
#                 [51.5074, -0.1278],
#                 {}
#             ).addTo(map_d8ab33a78be96bc6fed0566df933291d);
#
#
#         var popup_b909b3bd61fca4ec3decd3db42a5eea0 = L.popup({&quot;maxWidth&quot;: &quot;auto&quot;});
#
#
#
#                 var html_895123210d703fe40a3a6f2d88260e77 = $(`&lt;div id=&quot;html_895123210d703fe40a3a6f2d88260e77&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;London&lt;/b&gt;&lt;br&gt;&lt;img src=&#x27;https://source.unsplash.com/400x300/?london&#x27; width=&#x27;200px&#x27;&gt;&lt;/div&gt;`)[0];
#                 popup_b909b3bd61fca4ec3decd3db42a5eea0.setContent(html_895123210d703fe40a3a6f2d88260e77);
#
#
#
#         marker_bb0123a315e4ad4fcbf6bf5a716a15de.bindPopup(popup_b909b3bd61fca4ec3decd3db42a5eea0)
#         ;
#
#
#
#
#             var marker_f49b11344113bb68be90cc0d20021ef4 = L.marker(
#                 [35.6895, 139.6917],
#                 {}
#             ).addTo(map_d8ab33a78be96bc6fed0566df933291d);
#
#
#         var popup_bff8693cd03b9b03570e2d94a0b35388 = L.popup({&quot;maxWidth&quot;: &quot;auto&quot;});
#
#
#
#                 var html_ab31359d0bb1b3f2e246daed0a5af2af = $(`&lt;div id=&quot;html_ab31359d0bb1b3f2e246daed0a5af2af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Tokyo&lt;/b&gt;&lt;br&gt;&lt;img src=&#x27;https://source.unsplash.com/400x300/?tokyo&#x27; width=&#x27;200px&#x27;&gt;&lt;/div&gt;`)[0];
#                 popup_bff8693cd03b9b03570e2d94a0b35388.setContent(html_ab31359d0bb1b3f2e246daed0a5af2af);
#
#
#
#         marker_f49b11344113bb68be90cc0d20021ef4.bindPopup(popup_bff8693cd03b9b03570e2d94a0b35388)
#         ;
#
#
#
#
#             var marker_933e67b17279015c5513cbc74271d280 = L.marker(
#                 [-33.85903383272798, 151.20364678216654],
#                 {}
#             ).addTo(map_d8ab33a78be96bc6fed0566df933291d);
#
#
#         var popup_c3f56ad19bb6bc69c0d799d4d9bff1c1 = L.popup({&quot;maxWidth&quot;: &quot;auto&quot;});
#
#
#
#                 var html_962431b56bb699dc651efb35ac2bbd99 = $(`&lt;div id=&quot;html_962431b56bb699dc651efb35ac2bbd99&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Sydney&lt;/b&gt;&lt;br&gt;&lt;img src=&#x27;https://source.unsplash.com/400x300/?sydney&#x27; width=&#x27;200px&#x27;&gt;&lt;/div&gt;`)[0];
#                 popup_c3f56ad19bb6bc69c0d799d4d9bff1c1.setContent(html_962431b56bb699dc651efb35ac2bbd99);
#
#
#
#         marker_933e67b17279015c5513cbc74271d280.bindPopup(popup_c3f56ad19bb6bc69c0d799d4d9bff1c1)
#         ;
#
#
#
#
#             var marker_8355a445d6214e3c4ed8632890deb4c4 = L.marker(
#                 [27.17540725072536, 78.04222802682138],
#                 {}
#             ).addTo(map_d8ab33a78be96bc6fed0566df933291d);
#
#
#         var popup_41db92a6d31eaf3acdb88699a5fe9aa4 = L.popup({&quot;maxWidth&quot;: &quot;auto&quot;});
#
#
#
#                 var html_4fc933abd70c4529deb7bf220bfbc42b = $(`&lt;div id=&quot;html_4fc933abd70c4529deb7
